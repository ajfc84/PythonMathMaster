# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
A = [[1, 2], [1, 4]]
A
# Out:
# [[1, 2], [1, 4]]

# %%
plt.imshow(A)
plt.xticks([0, 1])
plt.yticks([0, 1])
# Out:
# ([<matplotlib.axis.YTick at 0x7fb90adaf1f0>,
# ...
#  <a list of 2 Text major ticklabel objects>)

# %%
A = np.zeros((10, 14))

for i in range(0, 10):
    for j in range(0, 14):
        A[i, j] = 3*i - 4*j
        plt.text(j, i, A[i, j])
plt.imshow(A)
